# %%
from google_play_scraper import app, Sort, reviews_all
import pandas as pd
import numpy as np
import json, os, uuid
import glob

import json
from time import sleep
from typing import List, Optional, Tuple
from google_play_scraper import Sort
from google_play_scraper.constants.element import ElementSpecs
from google_play_scraper.constants.regex import Regex
from google_play_scraper.constants.request import Formats
from google_play_scraper.utils.request import post

from datetime import datetime
from tqdm import tqdm
import time

# %%
path = r"C:\Users\KARINA\TEST SKRIPSI\Scraping Data Skripsi\Scraping Fix" # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))

df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
df
# Out:
#             source                             review_id          review_date  \
# 0        App Store  b516031e-aa43-4722-9f00-0f859e9e1d77  2023-07-01 09:15:27
# 1        App Store  38956518-e4f1-418c-a031-e287aef70b59  2023-03-07 18:18:44
# 2        App Store  9b2b4724-fbc8-4992-a305-e491e2ca1cf6  2023-11-22 06:01:03
# 3        App Store  c5a10e5f-dab0-4e31-b1d1-f6bca44bdb1d  2023-02-28 11:26:54
# 4        App Store  8ac64cb2-3322-4ff8-97f5-b26ebe22d1c6  2024-02-03 06:25:11
# ...            ...                                   ...                  ...
# 14127  Google Play  131f21bc-8c6a-454b-9498-d0274276c8c8  2019-05-02 08:18:12
# 14128  Google Play  ec1e0f9c-338c-4cd6-a8e7-06eb2113d896  2019-05-02 07:53:50
# 14129  Google Play  e0d6a823-7d42-475e-a842-c88a587e59a4  2019-05-02 07:30:47
# 14130  Google Play  81e13f53-db4a-46c2-aa59-267268df0b7b  2019-05-02 05:31:40
# 14131  Google Play  0cdc25aa-4b5a-4eed-a51e-5022c67d3566  2019-05-02 03:46:48
#
# ...

# %%
df.to_csv(r'C:\Users\KARINA\OneDrive\Desktop\Skripsi Alam VS Code\Scraping\Scrapping.csv', index = False)

# %%
df = pd.read_csv(r'C:\Users\KARINA\OneDrive\Desktop\Skripsi Alam VS Code\PreprocessUjiCoba.csv')
df
# Out:
#                                                     text  rating       source  \
# 0      Tolong diperbaiki untuk order online Via aplik...       2    App Store
# 1      perasaan pswrd udah bener, pas log in coba aku...       1    App Store
# 2      Halo admin \nKenapa aplikasinya sejak 2 minggu...       2    App Store
# 3                                         very very bad🦶       1    App Store
# 4                                Kode refal : IMA-5B5A39       5    App Store
# ...                                                  ...     ...          ...
# 14127                                               good       5  Google Play
# 14128                                               good       5  Google Play
# 14129                                               cool       5  Google Play
# 14130                             i am happy to have it!       5  Google Play
# 14131  My card cant be used, always failed when the b...       5  Google Play
#
# ...

# %%
df = df[['stemming']]
df
# Out:
#                                                 stemming
# 0      tolong baik order online via aplikasi starbuck...
# 1      asa password bener pas log in coba klik lupa s...
# 2      halo admin aplikasi minggu akses terang overdu...
# 3                                          very very bad
# 4                                   kode refal ima5b5a39
# ...                                                  ...
# 14127                                               good
# 14128                                               good
# 14129                                               cool
# 14130                              i am happy to have it
# 14131  my card cant be used always failed when the ba...
#
# [14132 rows x 1 columns]

# %%
df['stemming'] = df['stemming'].astype(str)
# Out:
# C:\Users\KARINA\AppData\Local\Temp\ipykernel_14616\1625522594.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['stemming'] = df['stemming'].astype(str)

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# Download the VADER lexicon for sentiment analysis
nltk.download('vader_lexicon')

# Initialize the VADER sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Function to assign labels based on sentiment scores
def label_sentiment(text):
    # Get sentiment scores
    scores = sia.polarity_scores(text)
    
    # Classify as positive, negative, or neutral based on compound score
    if scores['compound'] >= 0.05:
        return 'positive'
    elif scores['compound'] <= -0.05:
        return 'negative'
    else:
        return 'negative'

# Apply the function to each review description
df['sentiment_label'] = df['stemming'].apply(label_sentiment)
df
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\KARINA\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# C:\Users\KARINA\AppData\Local\Temp\ipykernel_14616\2563799022.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentiment_label'] = df['stemming'].apply(label_sentiment)
#                                                 stemming sentiment_label
# 0      tolong baik order online via aplikasi starbuck...        negative
# 1      asa password bener pas log in coba klik lupa s...        negative
# 2      halo admin aplikasi minggu akses terang overdu...        negative
# 3                                          very very bad        negative
# ...

# %%
df.to_csv(r'C:\Users\KARINA\OneDrive\Desktop\Skripsi Alam VS Code\LabellingUjiCoba.csv', index = False)
