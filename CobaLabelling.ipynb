# %%
from google_play_scraper import app, Sort, reviews_all
import pandas as pd
import numpy as np
import json, os, uuid
import glob

import json
from time import sleep
from typing import List, Optional, Tuple
from google_play_scraper import Sort
from google_play_scraper.constants.element import ElementSpecs
from google_play_scraper.constants.regex import Regex
from google_play_scraper.constants.request import Formats
from google_play_scraper.utils.request import post

from datetime import datetime
from tqdm import tqdm
import time

# %%
path = r"C:\Users\KARINA\TEST SKRIPSI\Scraping Data Skripsi\Scraping Fix" # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))

df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
df
# Out:
#             source                             review_id          review_date  \
# 0        App Store  b516031e-aa43-4722-9f00-0f859e9e1d77  2023-07-01 09:15:27
# 1        App Store  38956518-e4f1-418c-a031-e287aef70b59  2023-03-07 18:18:44
# 2        App Store  9b2b4724-fbc8-4992-a305-e491e2ca1cf6  2023-11-22 06:01:03
# 3        App Store  c5a10e5f-dab0-4e31-b1d1-f6bca44bdb1d  2023-02-28 11:26:54
# 4        App Store  8ac64cb2-3322-4ff8-97f5-b26ebe22d1c6  2024-02-03 06:25:11
# ...            ...                                   ...                  ...
# 14127  Google Play  131f21bc-8c6a-454b-9498-d0274276c8c8  2019-05-02 08:18:12
# 14128  Google Play  ec1e0f9c-338c-4cd6-a8e7-06eb2113d896  2019-05-02 07:53:50
# 14129  Google Play  e0d6a823-7d42-475e-a842-c88a587e59a4  2019-05-02 07:30:47
# 14130  Google Play  81e13f53-db4a-46c2-aa59-267268df0b7b  2019-05-02 05:31:40
# 14131  Google Play  0cdc25aa-4b5a-4eed-a51e-5022c67d3566  2019-05-02 03:46:48
#
# ...

# %%
df.to_csv(r'C:\Users\KARINA\OneDrive\Desktop\Skripsi Alam VS Code\Scraping\Scrapping.csv', index = False)

# %%
df = pd.read_csv(r'C:\Users\KARINA\OneDrive\Desktop\Skripsi Alam VS Code\Translate\Translated.csv')
df
# Out:
#                                       review_description  \
# 0      Swear to God this app is made by amateurs. The...
# 1      The idea of this app is great and its very use...
# 2      After the last 2 updates this app became annoy...
# 3      The input pin is very annoying. Because when y...
# 4      The apps keeps kicking me out from the apps. E...
# ...                                                  ...
# 13061                                               good
# 13062                                               good
# 13063                                               cool
# 13064                             i am happy to have it!
# 13065  My card cant be used, always failed when the b...
#
#                                          translated_text
# 0      Sumpah, aplikasi ini dibuat oleh para amatir. ...
# 1      Gagasan tentang aplikasi ini sangat bagus dan ...
# 2      Setelah 2 pemutakhiran terakhir aplikasi ini m...
# ...

# %%
df['translated_text'] = df['translated_text'].astype(str)

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# download
nltk.download('vader_lexicon')

sia = SentimentIntensityAnalyzer()


def label_sentiment(text):
    
    scores = sia.polarity_scores(text)
    
    if scores['compound'] >= 0.05:
        return 'positive'
    elif scores['compound'] <= -0.05:
        return 'negative'
    else:
        return 'negative'


df['sentiment'] = df['translated_text'].apply(label_sentiment)
df.head(20)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\KARINA\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#                                    review_description  \
# 0   Swear to God this app is made by amateurs. The...
# 1   The idea of this app is great and its very use...
# 2   After the last 2 updates this app became annoy...
# 3   The input pin is very annoying. Because when y...
# 4   The apps keeps kicking me out from the apps. E...
# 5   App sucks. No information regarding how many r...
# 6   This app is useful, but once logged out, can't...
# 7   Traveling in Indonesia and my US Sbux doesn't ...
# 8   It was good, now it is just rubbish. From the ...
# 9   I can't login! They ask me to relogin like onc...
# 10  This app just like a beginner who starting lea...
# 11  Absolutely garbage. The only people giving it ...
# 12  Need many improvements. Oftentimes won't even ...
# ...

# %%
df.to_csv(r'C:\Users\KARINA\OneDrive\Desktop\Skripsi Alam VS Code\Labelling\Labelling.csv', index = False)
